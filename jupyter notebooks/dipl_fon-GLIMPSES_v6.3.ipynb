# %% [markdown]
# # Analiza 'glipses' u govornom materijalu

# %%
work_version_num = 6.3
word_version_suffix = ""
work_version = f"v{work_version_num}{word_version_suffix}"

print(work_version)
# Out:
# v6.3

# %% [markdown]
# # [1] Generating a structured nested dictionary

# %%
# Define the structure of the nested dictionary
data = {
    'SNR_-2': {
        'govornik_1': {},
        'govornik_2': {},
        'govornik_3': {},
        'govornik_4': {}
    },
    'SNR_+0': {
        'govornik_1': {},
        'govornik_2': {},
        'govornik_3': {},
        'govornik_4': {}
    },
    'SNR_+2': {
        'govornik_1': {},
        'govornik_2': {},
        'govornik_3': {},
        'govornik_4': {}
    }
}

# Define the stimuli
stimuli = ['apa',
           'ata',
           'aka',
           'aba',
           'ada',
           'aga',
           'asa',
           'aša',
           'aza',
           'aža',
           'afa',
           'aha',
           'aca',
           'ača',
           'ađa',
           'aja',
           'ana',
           'ama',
           'ara',
           'ala',
           'ava']

# Initialize the nested dictionary with empty lists for each stimulus
for snr in data:
    for speaker in data[snr]:
        for stimulus in stimuli:
            data[snr][speaker][stimulus] = []

print(f"len(data): {len(data)}")  # Prints the number of keys at the top level of data
print(f"data.keys(): {data.keys()}\n")  # Prints all keys at the top level of data
print(f"data['SNR_-2'].keys(): {(data['SNR_-2'].keys())}")
print(f"len(data['SNR_-2'].keys()): {len(data['SNR_-2'].keys())}\n")  # Prints the number of keys at the next level (assuming snr[0] exists in data)

print(f"data['SNR_-2']['govornik_1'].keys(): {(data['SNR_-2']['govornik_1'].keys())}")
print(f"len(data['SNR_-2'].keys()): {len(data['SNR_-2']['govornik_1'].keys())}\n")  # Prints the number of keys at the next level (assuming snr[0] exists in data)

#print(f"data['SNR_-2']['govornik_1']['apa'].keys(): {(data['SNR_-2']['govornik_1']['apa'].keys())}")
print(f"len(data['SNR_-2']['govornik_1']['apa'].keys()): {len(data['SNR_-2']['govornik_1']['apa'])}\n")  # Prints the number of keys at the next level (assuming snr[0] exists in data)
# Out:
# len(data): 3
# data.keys(): dict_keys(['SNR_-2', 'SNR_+0', 'SNR_+2'])
#
# data['SNR_-2'].keys(): dict_keys(['govornik_1', 'govornik_2', 'govornik_3', 'govornik_4'])
# len(data['SNR_-2'].keys()): 4
#
# data['SNR_-2']['govornik_1'].keys(): dict_keys(['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava'])
# len(data['SNR_-2'].keys()): 21
#
# len(data['SNR_-2']['govornik_1']['apa'].keys()): 0

# %%
# Print the number of noise conditions
print(f"Number of noise conditions: {len(data)}")
print(f"Noise conditions: {list(data.keys())}")

# Iterate over each noise condition to print the number of speakers and stimuli
for snr_condition, speakers in data.items():
    print(f"\nNoise condition: {snr_condition}")
    
    # Number of speakers in the current noise condition
    num_speakers = len(speakers)
    print(f"  Number of speakers: {num_speakers}")
    print(f"  Speakers: {list(speakers.keys())}")
    
    # Iterate over each speaker to print the number of stimuli
    for speaker, stimuli in speakers.items():
        num_stimuli = len(stimuli)
        print(f"    Speaker: {speaker}")
        print(f"      Number of stimuli: {num_stimuli}")
        print(f"      Stimuli: {list(stimuli.keys())}")
# Out:
# Number of noise conditions: 3
# Noise conditions: ['SNR_-2', 'SNR_+0', 'SNR_+2']
#
# Noise condition: SNR_-2
#   Number of speakers: 4
#   Speakers: ['govornik_1', 'govornik_2', 'govornik_3', 'govornik_4']
#     Speaker: govornik_1
#       Number of stimuli: 21
#       Stimuli: ['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava']
#     Speaker: govornik_2
#       Number of stimuli: 21
#       Stimuli: ['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava']
#     Speaker: govornik_3
#       Number of stimuli: 21
#       Stimuli: ['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava']
#     Speaker: govornik_4
#       Number of stimuli: 21
#       Stimuli: ['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava']
#
# Noise condition: SNR_+0
#   Number of speakers: 4
#   Speakers: ['govornik_1', 'govornik_2', 'govornik_3', 'govornik_4']
#     Speaker: govornik_1
#       Number of stimuli: 21
#       Stimuli: ['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava']
#     Speaker: govornik_2
#       Number of stimuli: 21
#       Stimuli: ['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava']
#     Speaker: govornik_3
#       Number of stimuli: 21
#       Stimuli: ['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava']
#     Speaker: govornik_4
#       Number of stimuli: 21
#       Stimuli: ['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava']
#
# Noise condition: SNR_+2
#   Number of speakers: 4
#   Speakers: ['govornik_1', 'govornik_2', 'govornik_3', 'govornik_4']
#     Speaker: govornik_1
#       Number of stimuli: 21
#       Stimuli: ['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava']
#     Speaker: govornik_2
#       Number of stimuli: 21
#       Stimuli: ['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava']
#     Speaker: govornik_3
#       Number of stimuli: 21
#       Stimuli: ['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava']
#     Speaker: govornik_4
#       Number of stimuli: 21
#       Stimuli: ['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava']

# %%
def explore_dict(d, level=0):
    indent = "  " * level
    if isinstance(d, dict):
        for key, value in d.items():
            print(f"{indent}Key: {key} (Type: {type(value).__name__})")
            explore_dict(value, level + 1)
    elif isinstance(d, list):
        if len(d) > 0:
            print(f"{indent}List of {len(d)} items (Type: {type(d[0]).__name__})")
        else:
            print(f"{indent}Empty list")
    else:
        print(f"{indent}Value: {d} (Type: {type(d).__name__})")

# Example usage
explore_dict(data)

# %% [markdown]
# # Skip to [7] for MFCC

# %% [markdown]
# # [2] Main audio file STFT analysis and dict populating

# %% [markdown]
# Takes about 34s to finish

# %%
# %%time

import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from scipy.io import wavfile
from scipy.signal import stft

# Define parameters
speakers = ['govornik_1', 'govornik_2', 'govornik_3', 'govornik_4']
snr_conditions = ['SNR_-2', 'SNR_+0', 'SNR_+2']

# Map speaker to SSN_gX part
speaker_mapping = {
    'govornik_1': 'g1',
    'govornik_2': 'g2',
    'govornik_3': 'g3',
    'govornik_4': 'g4'
}

# Map SNR condition to the corresponding number
snr_mapping = {
    'SNR_-2': '70',
    'SNR_+0': '68',
    'SNR_+2': '66'
}

# SNR filename prefix mapping
snr_prefix_mapping = {
    'SNR_-2': 'S1',
    'SNR_+0': 'S2',
    'SNR_+2': 'S3'
}

# Base paths
base_path = r'C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\SSN all all'
base_speech_mask_path = r'C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV'

# Initialize the data dictionary
data = {snr: {speaker: {} for speaker in speakers} for snr in snr_conditions}

def process_and_store_data(speaker, snr_condition, stimulus, speech_mask_file_path, mask, sr, snr_prefix):
    # Load the speech + mask audio file
    _, speech_mask = wavfile.read(speech_mask_file_path)

    # Determine the minimum length of the audio files
    min_length = min(len(mask), len(speech_mask))

    # Trim the audio files to the minimum length
    mask = mask[:min_length]
    speech_mask = speech_mask[:min_length]

    # Compute STFT
    f, t, mask_stft = stft(mask, sr)
    _, _, speech_mask_stft = stft(speech_mask, sr)

    # Convert to power spectrograms (magnitude squared)
    mask_power = np.abs(mask_stft)**2 # Adding a slightly larger value to avoid division by zero
    speech_mask_power = np.abs(speech_mask_stft)**2

    # Calculate SNR
    snr = 10 * np.log10(speech_mask_power / (mask_power + 1e-3))  # Adding a slightly larger value to avoid division by zero

    # Normalize SNR values to the range [0, 1]
    snr_normalized = (snr - np.min(snr)) / (np.max(snr) - np.min(snr))

    # Set values where SNR <= 3 to 0
    glimpses = np.where(snr > 3, snr_normalized, 0)
    
    # Trim the glimpses array if its length is longer than the shortest length
    shortest_length = min(len(glimpses[1]), len(mask))  # Calculate the shortest length among glimpses and mask
    if len(glimpses[1]) > shortest_length:  # Check the length along the second axis
        trim_length = len(glimpses[1]) - shortest_length
        trim_start = trim_length // 2
        trim_end = len(glimpses[1]) - (trim_length - trim_start)
        glimpses = glimpses[:, trim_start:trim_end]  # Trim along the second axis

    # Store the data in the dictionary
    data[snr_condition][speaker][stimulus] = {
        'original': speech_mask,
        'mask': mask,
        'glimpses': glimpses,
        'time': t,
        'frequency': f
    }

    # Visualize the glimpses on the spectrogram
    plt.figure(figsize=(10, 3))
    plt.pcolormesh(t, f, glimpses, shading='nearest', cmap='gray_r', vmin=0, vmax=1)
    
    title = f'{snr_prefix}{stimulus}'
    plt.title(title + ' - Glimpses (SNR > 3 dB)')
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [sec]')
    plt.tight_layout()
    
    # Save the plot as a .png file in the same directory, including the SNR prefix
    output_filename = os.path.join(os.path.dirname(speech_mask_file_path), f'{title}.png'.replace(' ', '_'))
    plt.savefig(output_filename, format='png', bbox_inches='tight')
    plt.close()  # Close the plot to free memory




# Iterate over all speakers and SNR conditions
for speaker in speakers:
    for snr_condition in snr_conditions:
        ssn_part = speaker_mapping[speaker]
        snr_number = snr_mapping[snr_condition]

        # Construct the mask_dir path using string formatting
        mask_dir = f'{base_path}\SSN_{ssn_part}_{snr_number}.wav'
        
        # Construct the speech_mask_dir path using string formatting
        speech_mask_folder_mapping = {
            'govornik_1': 'wav g1 VCV mask',
            'govornik_2': 'wav g2 VCV mask',
            'govornik_3': 'wav g3 VCV mask',
            'govornik_4': 'wav g4 VCV mask'
        }
        speech_mask_folder = speech_mask_folder_mapping[speaker]
        speech_mask_dir = os.path.join(base_speech_mask_path, speech_mask_folder)

        print(f"Processing speaker: {speaker}, SNR condition: {snr_condition}\n")
        #print(f"mask_dir: {mask_dir}")
        #print(f"speech_mask_dir: {speech_mask_dir}")

        # Load the mask file
        sr, mask = wavfile.read(mask_dir)

        # Get the correct SNR prefix for the current SNR condition
        snr_prefix = snr_prefix_mapping[snr_condition]

        # List all files in the speaker's directory
        speech_mask_filenames = [f for f in os.listdir(speech_mask_dir) if f.endswith('.wav') and f.startswith(snr_prefix)]

        print(f"speech_mask_filenames: {speech_mask_filenames[:2]} ... (total {len(speech_mask_filenames)})\n")

        # Process each file
        for speech_mask_filename in speech_mask_filenames:
            speech_mask_file_path = os.path.join(speech_mask_dir, speech_mask_filename)
            stimulus = os.path.splitext(speech_mask_filename)[0][2:]  # Extract the stimulus part of the filename
            process_and_store_data(speaker, snr_condition, stimulus, speech_mask_file_path, mask, sr, snr_prefix)

# Check data dictionary content
print(f"\nlen(data): {len(data)}")
print(f"data.keys(): {data.keys()}\n")
# Out:
# Processing speaker: govornik_1, SNR condition: SNR_-2
#
# speech_mask_filenames: ['S1aba.wav', 'S1aca.wav'] ... (total 21)
#
# Processing speaker: govornik_1, SNR condition: SNR_+0
#
# speech_mask_filenames: ['S2aba.wav', 'S2aca.wav'] ... (total 21)
#
# Processing speaker: govornik_1, SNR condition: SNR_+2
#
# speech_mask_filenames: ['S3aba.wav', 'S3aca.wav'] ... (total 21)
#
# Processing speaker: govornik_2, SNR condition: SNR_-2
#
# speech_mask_filenames: ['S1aba.wav', 'S1aca.wav'] ... (total 21)
#
# Processing speaker: govornik_2, SNR condition: SNR_+0
#
# speech_mask_filenames: ['S2aba.wav', 'S2aca.wav'] ... (total 21)
#
# Processing speaker: govornik_2, SNR condition: SNR_+2
#
# speech_mask_filenames: ['S3aba.wav', 'S3aca.wav'] ... (total 21)
#
# Processing speaker: govornik_3, SNR condition: SNR_-2
#
# speech_mask_filenames: ['S1aba.wav', 'S1aca.wav'] ... (total 21)
# <timed exec>:61: RuntimeWarning: divide by zero encountered in log10
# <timed exec>:64: RuntimeWarning: invalid value encountered in subtract
# <timed exec>:64: RuntimeWarning: invalid value encountered in divide
# Processing speaker: govornik_3, SNR condition: SNR_+0
#
# speech_mask_filenames: ['S2aba.wav', 'S2aca.wav'] ... (total 21)
#
# Processing speaker: govornik_3, SNR condition: SNR_+2
#
# speech_mask_filenames: ['S3aba.wav', 'S3aca.wav'] ... (total 21)
#
# Processing speaker: govornik_4, SNR condition: SNR_-2
#
# speech_mask_filenames: ['S1aba.wav', 'S1aca.wav'] ... (total 21)
#
# Processing speaker: govornik_4, SNR condition: SNR_+0
#
# speech_mask_filenames: ['S2aba.wav', 'S2aca.wav'] ... (total 21)
#
# Processing speaker: govornik_4, SNR condition: SNR_+2
#
# speech_mask_filenames: ['S3aba.wav', 'S3aca.wav'] ... (total 21)
#
#
# len(data): 3
# data.keys(): dict_keys(['SNR_-2', 'SNR_+0', 'SNR_+2'])
#
# CPU times: total: 32.6 s
# Wall time: 34 s

# %% [markdown]
# ## CHECK if dictionary had filled properly

# %%
# Function to print sample data points
def print_sample_data(data, num_samples=3):
    for snr_condition, snr_data in data.items():
        print(f"SNR Condition: {snr_condition}")
        for speaker, speaker_data in snr_data.items():
            print(f"\tSpeaker: {speaker}")
            for stimulus, stimulus_data in speaker_data.items():
                print(f"\t\tStimulus: {stimulus}")
                print(f"\t\t\tOriginal Shape: {stimulus_data['original'].shape}")
                print(f"\t\t\tMask Shape: {stimulus_data['mask'].shape}")
                print(f"\t\t\tGlimpses Shape: {stimulus_data['glimpses'].shape}")
                print(f"\t\t\tGlimpses Example:")
                print(stimulus_data['glimpses'][:8, :5])  # Print a small portion of the glimpses
                print(f"\t\t\tTime: {stimulus_data['time'].shape}")  # Print the shape of time array
                print(f"\t\t\tFrequency: {stimulus_data['frequency'].shape}")  # Print the shape of frequency array
                num_samples -= 1
                if num_samples <= 0:
                    return

# Call the function to print sample data points
print_sample_data(data)
# Out:
# SNR Condition: SNR_-2
# 	Speaker: govornik_1
# 	Speaker: govornik_2
# 	Speaker: govornik_3
# 	Speaker: govornik_4
# SNR Condition: SNR_+0
# 	Speaker: govornik_1
# 	Speaker: govornik_2
# 	Speaker: govornik_3
# 	Speaker: govornik_4
# SNR Condition: SNR_+2
# 	Speaker: govornik_1
# 	Speaker: govornik_2
# 	Speaker: govornik_3
# 	Speaker: govornik_4

# %% [markdown]
# ## [3] Save Dictionary (34MB)

# %%
import pickle
output_file_path_base = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV"
dictionary_name_version = f"\GM_data_dict-{work_version}.pkl"

# Define the file path to save the dictionary
output_file_path = output_file_path_base + dictionary_name_version

# Save the dictionary using pickle
with open(output_file_path, "wb") as file:
    pickle.dump(data, file)

print(f"Dictionary saved to {output_file_path}")
# Out:
# Dictionary saved to C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\GM_data_dict-v2.0.pkl

# %% [markdown]
# ## [4] Load Dictionary

# %%
import pickle

# Load the dictionary from the file
output_file_path = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\GM_data_dict-v2.0.pkl"

with open(output_file_path, "rb") as file:
    data = pickle.load(file)

print("Dictionary loaded successfully!")
# Out:
# Dictionary loaded successfully!

# %% [markdown]
# ## [5] Analysis: Average out by speakers, per SNR condition

# %%
save5_png_path = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\PNG analiza"

# %%
import numpy as np

# Define selected speakers and noise conditions
selected_speakers = ['govornik_1', 'govornik_2','govornik_3', 'govornik_4']
selected_noise_condition = 'SNR_+2'

# Function to find the longest time length
def find_longest_time_length(data, selected_speakers, selected_noise_condition):
    longest_length = 0
    for stimulus in data[selected_noise_condition][selected_speakers[0]]:
        for speaker in selected_speakers:
            glimpses_length = data[selected_noise_condition][speaker][stimulus]['glimpses'].shape[1]  # Get the length along the time axis
            if glimpses_length > longest_length:
                longest_length = glimpses_length
    return longest_length

# Function to pad glimpses to the longest time length equally on both sides
def pad_glimpses(glimpses, longest_length):
    total_padding = longest_length - glimpses.shape[1]
    left_padding = total_padding // 2
    right_padding = total_padding - left_padding
    pad_width = ((0, 0), (left_padding, right_padding))
    return np.pad(glimpses, pad_width, mode='constant', constant_values=0)

# Function to calculate the average glimpses for each stimulus
def calculate_average_glimpses(data, selected_speakers, selected_noise_condition):
    average_glimpses = {}
    longest_length = find_longest_time_length(data, selected_speakers, selected_noise_condition)
    
    # Pad the glimpses and calculate the average glimpses for each stimulus
    for stimulus in data[selected_noise_condition][selected_speakers[0]]:
        glimpses_sum = None
        
        # Iterate over each speaker for the current stimulus
        for speaker in selected_speakers:
            glimpses = data[selected_noise_condition][speaker][stimulus]['glimpses']
            padded_glimpses = pad_glimpses(glimpses, longest_length)
            
            # Initialize glimpses_sum if it's None
            if glimpses_sum is None:
                glimpses_sum = padded_glimpses
            else:
                # Add the padded glimpses to the existing sum
                glimpses_sum += padded_glimpses
        
        # Calculate the average glimpses for the current stimulus
        average_glimpses[stimulus] = glimpses_sum / len(selected_speakers)
    
    return average_glimpses

# Calculate the average glimpses
average_glimpses = calculate_average_glimpses(data, selected_speakers, selected_noise_condition)

# Visualize and save the averaged glimpses
for stimulus, glimpses in average_glimpses.items():
    print(f"Plotting: {selected_noise_condition} - {stimulus}")
    print("Glimpses shape before plotting:", glimpses.shape)

    plt.figure(figsize=(8, 6))
    plt.pcolormesh(range(glimpses.shape[1]), range(glimpses.shape[0]), glimpses, shading='nearest', cmap='gray_r', vmin=0, vmax=1)
    
    plt.title(f'{selected_noise_condition} - {stimulus} - Average Glimpses')
    plt.ylabel('Frequency [bins]')
    plt.xlabel('Time [bins]')
    plt.tight_layout()
    
    # Save the plot as a .png file in the current directory
    speaker_suffix = '+'.join([speaker_mapping[speaker] for speaker in selected_speakers])
    snr_prefix = snr_prefix_mapping[selected_noise_condition]
    output_filename = f'{stimulus}_avg_glimpses_{snr_prefix}-{speaker_suffix}.png'.replace(' ', '_')
    plt.savefig(os.path.join(save5_png_path, output_filename), format='png', bbox_inches='tight')
    plt.close()
# Out:
# Plotting: SNR_+2 - aba
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - aca
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - ada
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - afa
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - aga
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - aha
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - aja
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - aka
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - ala
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - ama
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - ana
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - apa
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - ara
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - asa
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - ata
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - ava
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - aza
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - ača
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - ađa
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - aša
# Glimpses shape before plotting: (129, 161)
# Plotting: SNR_+2 - aža
# Glimpses shape before plotting: (129, 161)

# %% [markdown]
# ## visual debugger - before and after, saves them

# %% [markdown]
# ## [6] PyTorch testing

# %%
import torchaudio
import torch
import matplotlib.pyplot as plt

torch_test = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1aša.wav"

# Load the audio file
waveform, sample_rate = torchaudio.load(torch_test)


# Resample to a common sample rate (optional)
waveform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000)(waveform)

# Convert to mono if stereo
if waveform.shape[0] > 1:
    waveform = torch.mean(waveform, dim=0, keepdim=True)

# Compute the log-mel spectrogram
mel_specgram = torchaudio.transforms.MelSpectrogram(
    sample_rate=16000, n_fft=400, win_length=400, hop_length=160, n_mels=64
)(waveform)

# Convert to decibels
log_mel_specgram = torchaudio.transforms.AmplitudeToDB()(mel_specgram)

# Plot the log-mel spectrogram
plt.figure(figsize=(10, 4))
plt.imshow(log_mel_specgram[0].numpy(), cmap='viridis', origin='lower', aspect='auto')
plt.title('Log-Mel Spectrogram')
plt.xlabel('Time')
plt.ylabel('Mel Filterbank Index')
plt.colorbar(format='%+2.0f dB')
plt.show()

# %%
# Calculate the average glimpses
average_glimpses = calculate_average_glimpses(data, selected_speakers, selected_noise_condition)

# Visualize the averaged glimpses
for i, (stimulus, glimpses) in enumerate(average_glimpses.items()):
    if i >= 2:  # Only visualize the first two stimuli
        break
    
    print(f"Plotting: {selected_noise_condition} - {stimulus}")
    print("Glimpses shape before plotting:", glimpses.shape)
    
    # Define a reversed grayscale colormap
    reversed_gray_cmap = plt.cm.gray.reversed()
    
    plt.figure(figsize=(12, 6))
    
    # Plot original glimpses
    plt.subplot(2, 2, 1)
    plt.pcolormesh(data[selected_noise_condition][selected_speakers[0]][stimulus]['glimpses'], shading='nearest', cmap=reversed_gray_cmap, vmin=0, vmax=1)
    plt.title(f'{selected_noise_condition} - {stimulus} - Original Glimpses')
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [sec]')
    
    plt.subplot(2, 2, 2)
    plt.pcolormesh(data[selected_noise_condition][selected_speakers[1]][stimulus]['glimpses'], shading='nearest', cmap=reversed_gray_cmap, vmin=0, vmax=1)
    plt.title(f'{selected_noise_condition} - {stimulus} - Original Glimpses')
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [sec]')
    
    # Plot averaged glimpses
    plt.subplot(2, 2, 3)
    plt.pcolormesh(glimpses, shading='nearest', cmap=reversed_gray_cmap, vmin=0, vmax=1)
    plt.title(f'{selected_noise_condition} - {stimulus} - Average Glimpses')
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [sec]')
    
    plt.subplot(2, 2, 4)
    plt.pcolormesh(glimpses, shading='nearest', cmap=reversed_gray_cmap, vmin=0, vmax=1)
    plt.title(f'{selected_noise_condition} - {stimulus} - Average Glimpses')
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [sec]')
    
    plt.tight_layout()
    
    # Display the plots
    plt.show()
# Out:
# Plotting: SNR_-2 - aba
# Glimpses shape before plotting: (129, 107)
# Plotting: SNR_-2 - aca
# Glimpses shape before plotting: (129, 107)

# %%
# Plot original glimpses
plt.subplot(2, 2, 1)
plt.imshow(data[selected_noise_condition][selected_speakers[0]][stimulus]['glimpses'], aspect='auto', cmap=reversed_gray_cmap, origin='lower', extent=[0, 1, 0, 1])
plt.title(f'{selected_noise_condition} - {stimulus} - Original Glimpses')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')

plt.subplot(2, 2, 2)
plt.imshow(data[selected_noise_condition][selected_speakers[1]][stimulus]['glimpses'], aspect='auto', cmap=reversed_gray_cmap, origin='lower', extent=[0, 1, 0, 1])
plt.title(f'{selected_noise_condition} - {stimulus} - Original Glimpses')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Plot original glimpses
#       2 plt.subplot(2, 2, 1)
# ----> 3 plt.imshow(data[selected_noise_condition][selected_speakers[0]][stimulus]['glimpses'], aspect='auto', cmap=reversed_gray_cmap, origin='lower', extent=[0, 1, 0, 1])
#       4 plt.title(f'{selected_noise_condition} - {stimulus} - Original Glimpses')
#       5 plt.ylabel('Frequency [Hz]')
#
# NameError: name 'reversed_gray_cmap' is not defined

# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# Define selected speakers and noise conditions
selected_speakers = ['govornik_1', 'govornik_3']
selected_noise_condition = 'SNR_-2'

# Function to calculate the average glimpses for each stimulus
def calculate_average_glimpses(data, selected_speakers, selected_noise_condition):
    average_glimpses = {}
    shortest_length = None
    
    # Find the shortest length
    for stimulus in data[selected_noise_condition][selected_speakers[0]]:
        glimpses_lengths = [len(data[selected_noise_condition][speaker][stimulus]['glimpses'][1]) for speaker in selected_speakers]  # Get the length along the second axis
        shortest_length = min(glimpses_lengths) if shortest_length is None else min(shortest_length, *glimpses_lengths)
    
    #print("Shortest length:", shortest_length)  # Add print statement to check the shortest length
    
    # Calculate the average glimpses for each stimulus
    for stimulus in data[selected_noise_condition][selected_speakers[0]]:
        glimpses_sum = None
        
        # Iterate over each speaker for the current stimulus
        for speaker in selected_speakers:
            glimpses = data[selected_noise_condition][speaker][stimulus]['glimpses']
            
            # Trim the glimpses array if its length is longer than the shortest length
            if len(glimpses[1]) > shortest_length:  # Check the length along the second axis
                trim_length = len(glimpses[1]) - shortest_length
                trim_start = trim_length // 2
                trim_end = len(glimpses[1]) - (trim_length - trim_start)
                glimpses = glimpses[:, trim_start:trim_end]  # Trim along the second axis
                
            # Initialize glimpses_sum if it's None
            if glimpses_sum is None:
                glimpses_sum = glimpses
            else:
                # Add the glimpses to the existing sum
                glimpses_sum += glimpses
        
        # Calculate the average glimpses for the current stimulus
        average_glimpses[stimulus] = glimpses_sum / len(selected_speakers)
    
    return average_glimpses

# Calculate the average glimpses
average_glimpses = calculate_average_glimpses(data, selected_speakers, selected_noise_condition)

# Visualize and save the averaged glimpses
for stimulus, glimpses in average_glimpses.items():
    
    print(f"Plotting: {selected_noise_condition} - {stimulus}")
    
    # Define a reversed grayscale colormap
    reversed_gray_cmap = plt.cm.gray.reversed()
    
    plt.figure(figsize=(10, 3))
    plt.pcolormesh(glimpses, shading='nearest', cmap=reversed_gray_cmap, vmin=0, vmax=1)
    
    plt.title(f'{selected_noise_condition} - {stimulus} - Average Glimpses')
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [sec]')
    plt.tight_layout()
    
    # Save the plot as a .png file in the current directory
    output_filename = f'{stimulus}_average_glimpses.png'.replace(' ', '_')
    plt.savefig(os.path.join(save5_png_path, output_filename), format='png', bbox_inches='tight')
    plt.close()
# Out:
# Plotting: SNR_-2 - aba
# Plotting: SNR_-2 - aca
# Plotting: SNR_-2 - ada
# Plotting: SNR_-2 - afa
# Plotting: SNR_-2 - aga
# Plotting: SNR_-2 - aha
# Plotting: SNR_-2 - aja
# Plotting: SNR_-2 - aka
# Plotting: SNR_-2 - ala
# Plotting: SNR_-2 - ama
# Plotting: SNR_-2 - ana
# Plotting: SNR_-2 - apa
# Plotting: SNR_-2 - ara
# Plotting: SNR_-2 - asa
# Plotting: SNR_-2 - ata
# Plotting: SNR_-2 - ava
# Plotting: SNR_-2 - aza
# Plotting: SNR_-2 - ača
# Plotting: SNR_-2 - ađa
# Plotting: SNR_-2 - aša
# Plotting: SNR_-2 - aža

# %% [markdown]
# # [7] USING PYTORCH TORCHAUDIO MEL LOG SPECTROGRAMS

# %% [markdown]
# Takes 90s to make log_mel_spectrum and mfcc

# %%
# %%time

import torch
import torchaudio
import torchaudio.transforms as T
import torchaudio.functional as F
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from scipy.io import wavfile

# Define parameters
speakers = ['govornik_1', 'govornik_2', 'govornik_3', 'govornik_4']
snr_conditions = ['SNR_-2', 'SNR_+0', 'SNR_+2']

# Map speaker to SSN_gX part
speaker_mapping = {
    'govornik_1': 'g1',
    'govornik_2': 'g2',
    'govornik_3': 'g3',
    'govornik_4': 'g4'
}

# Map SNR condition to the corresponding number
snr_mapping = {
    'SNR_-2': '70',
    'SNR_+0': '68',
    'SNR_+2': '66'
}

# SNR filename prefix mapping
snr_prefix_mapping = {
    'SNR_-2': 'S1',
    'SNR_+0': 'S2',
    'SNR_+2': 'S3'
}

# Base paths
base_path = r'C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\SSN all all'
base_speech_mask_path = r'C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV'

n_fft = 400
win_length = 400
hop_length = 160
n_mels = 64

n_mfcc = 13 # drop the 0th to make 12
n_mfcc = 25 # drop the 0th to make 24

# Initialize the data dictionary
#data = {snr: {speaker: {} for speaker in speakers} for snr in snr_conditions}

#### THE MAIN TRANSFORMS HERE (Mel_spectrum and MFCC) ####
def process_and_store_data(speaker, snr_condition, stimulus, speech_mask_file_path, mask, sr, snr_prefix, n_fft, win_length, hop_length, n_mels, n_mfcc):
    # Load the speech + mask audio file
    speech_mask, sr = torchaudio.load(speech_mask_file_path)

    # Determine the minimum length of the audio files
    min_length_audio = min(mask.size(1), speech_mask.size(1))

    # Trim the audio files to the minimum length
    mask = mask[:, :min_length_audio]
    speech_mask = speech_mask[:, :min_length_audio]

    # Convert to log-mel spectrograms
    mel_transform = torchaudio.transforms.MelSpectrogram(sample_rate=sr,
                                                         n_fft=n_fft,
                                                         win_length=win_length,
                                                         hop_length=hop_length,
                                                         n_mels=n_mels)

    mfcc_transform = T.MFCC(sample_rate=sr,
                                n_mfcc=n_mfcc,
                                melkwargs={'n_fft': n_fft,
                                           'n_mels': n_mels,
                                           'hop_length': hop_length,
                                           'win_length': win_length})


    
   # Define transform for the power spectrogram
    spectrogram = T.Spectrogram(n_fft=128, power=2.0)  # power=2 for power spectrogram
    
    # Perform transform to get the power spectrograms
    mask_spec = spectrogram(mask)
    speech_mask_spec = spectrogram(speech_mask)
    
    # Convert power spectrogram to dB scale (if needed)
    mask_spec_db = T.AmplitudeToDB()(mask_spec)
    speech_mask_spec_db = T.AmplitudeToDB()(speech_mask_spec)

    snr_spec = speech_mask_spec_db - mask_spec_db
    #snr_normalized_spec = (snr_spec - snr_spec.min()) / (snr_spec.max() - snr_spec.min())


    snr_normalized_spec = snr_spec
    glimpses_spec = torch.where(snr_spec > 3, snr_normalized_spec, torch.zeros_like(snr_spec))



    
    mask_mel = mel_transform(mask)
    speech_mask_mel = mel_transform(speech_mask)

    # Convert to decibels
    log_mask_mel = torchaudio.transforms.AmplitudeToDB()(mask_mel)
    log_speech_mask_mel = torchaudio.transforms.AmplitudeToDB()(speech_mask_mel)

    # Calculate SNR
    snr = log_speech_mask_mel - log_mask_mel

    # Normalize SNR values to the range [0, 1]
    snr_normalized = (snr - snr.min()) / (snr.max() - snr.min())

    # Set values where SNR <= 3 to 0
    glimpses_mel = torch.where(snr > 3, snr_normalized, torch.zeros_like(snr))





    
    # Create DCT transformation matrix
    dct_matrix = F.create_dct(n_mfcc, n_mels, norm='ortho')
    
    # Apply DCT to the glimpses to get MFCCs
    glimpses_mfcc = torch.matmul(glimpses_mel.transpose(1, 2), dct_matrix).transpose(1, 2)

    




    
    # Store the data in the dictionary
    data[snr_condition][speaker][stimulus] = {
        'original': speech_mask,
        'mask': mask,
        'glimpses_mel': glimpses_mel,
        'glimpses_mfcc': glimpses_mfcc,
        'glimpses_spec': glimpses_spec
    }





     # Visualize the glimpses on the spectrogram (Mel)
    plt.figure(figsize=(8, 6))
    plt.imshow(glimpses_spec.squeeze().numpy(), cmap='gray_r', aspect='auto', origin='lower')
    title_spec = f'{snr_prefix}{stimulus}'
    plt.title(title_spec + ' - Glimpses (SNR > 3 dB) - Power Spectrogram')
    plt.ylabel('n_fft bins')
    plt.xlabel('Time [frames]')
    plt.tight_layout()

    # Save the Mel plot as a .png file in the same directory, including the SNR prefix
    output_filename_spec = os.path.join(os.path.dirname(speech_mask_file_path), f'{title_spec}_spec.png'.replace(' ', '_'))
    plt.savefig(output_filename_spec, format='png', bbox_inches='tight')
    plt.close()  # Close the plot to free memory
    print(output_filename_spec)



    

    # Visualize the glimpses on the spectrogram (Mel)
    plt.figure(figsize=(8, 6))
    plt.imshow(glimpses_mel.squeeze().numpy(), cmap='gray_r', aspect='auto', origin='lower')
    title_mel = f'{snr_prefix}{stimulus}_mel'
    plt.title(title_mel + ' - Glimpses (SNR > 3 dB) - Mel Spectrogram')
    plt.ylabel('Mel Filterbank Index')
    plt.xlabel('Time [frames]')
    plt.tight_layout()

    # Save the Mel plot as a .png file in the same directory, including the SNR prefix
    output_filename_mel = os.path.join(os.path.dirname(speech_mask_file_path), f'{title_mel}.png'.replace(' ', '_'))
    plt.savefig(output_filename_mel, format='png', bbox_inches='tight')
    plt.close()  # Close the plot to free memory

    # Visualize the glimpses on the spectrogram (MFCC)
    plt.figure(figsize=(8, 6))
    plt.imshow(glimpses_mfcc.squeeze().numpy(), cmap='gray_r', aspect='auto', origin='lower')
    title_mfcc = f'{snr_prefix}{stimulus}_mfcc'
    plt.title(title_mfcc + ' - Glimpses (SNR > 3 dB) - MFCC')
    plt.ylabel('MFCC Coefficients')
    plt.xlabel('Time [frames]')
    plt.tight_layout()

    # Save the MFCC plot as a .png file in the same directory, including the SNR prefix
    output_filename_mfcc = os.path.join(os.path.dirname(speech_mask_file_path), f'{title_mfcc}.png'.replace(' ', '_'))
    plt.savefig(output_filename_mfcc, format='png', bbox_inches='tight')
    plt.close()  # Close the plot to free memory



# Iterate over all speakers and SNR conditions
for speaker in speakers:
    for snr_condition in snr_conditions:
        ssn_part = speaker_mapping[speaker]
        snr_number = snr_mapping[snr_condition]

        # Construct the mask_dir path using string formatting
        mask_dir = f'{base_path}\SSN_{ssn_part}_{snr_number}.wav'
        
        # Construct the speech_mask_dir path using string formatting
        speech_mask_folder_mapping = {
            'govornik_1': 'wav g1 VCV mask',
            'govornik_2': 'wav g2 VCV mask',
            'govornik_3': 'wav g3 VCV mask',
            'govornik_4': 'wav g4 VCV mask'
        }
        speech_mask_folder = speech_mask_folder_mapping[speaker]
        speech_mask_dir = os.path.join(base_speech_mask_path, speech_mask_folder)

        print(f"Processing speaker: {speaker}, SNR condition: {snr_condition}\n")

        # Load the mask file
        mask, sr = torchaudio.load(mask_dir)

        # Get the correct SNR prefix for the current SNR condition
        snr_prefix = snr_prefix_mapping[snr_condition]

        # List all files in the speaker's directory
        speech_mask_filenames = [f for f in os.listdir(speech_mask_dir) if f.endswith('.wav') and f.startswith(snr_prefix)]

        print(f"speech_mask_filenames: {speech_mask_filenames[:2]} ... (total {len(speech_mask_filenames)})\n")

        # Process each file
        for speech_mask_filename in speech_mask_filenames:
            speech_mask_file_path = os.path.join(speech_mask_dir, speech_mask_filename)
            stimulus = os.path.splitext(speech_mask_filename)[0][2:]  # Extract the stimulus part of the filename
            #process_and_store_data(speaker, snr_condition, stimulus, speech_mask_file_path, mask, sr, snr_prefix)
            process_and_store_data(speaker, snr_condition, stimulus, speech_mask_file_path, mask, sr, snr_prefix, n_fft, win_length, hop_length, n_mels, n_mfcc)

# Check data dictionary content
print(f"\nlen(data): {len(data)}")
print(f"data.keys(): {data.keys()}\n")
# Out:
# Processing speaker: govornik_1, SNR condition: SNR_-2
#
# speech_mask_filenames: ['S1aba.wav', 'S1aca.wav'] ... (total 21)
#
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1aba_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1aca_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1ada_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1afa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1aga_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1aha_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1aja_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1aka_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1ala_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1ama_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1ana_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1apa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1ara_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1asa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1ata_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1ava_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1aza_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1ača_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1ađa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1aša_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S1aža_spec.png
# Processing speaker: govornik_1, SNR condition: SNR_+0
#
# speech_mask_filenames: ['S2aba.wav', 'S2aca.wav'] ... (total 21)
#
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2aba_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2aca_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2ada_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2afa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2aga_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2aha_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2aja_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2aka_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2ala_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2ama_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2ana_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2apa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2ara_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2asa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2ata_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2ava_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2aza_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2ača_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2ađa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2aša_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S2aža_spec.png
# Processing speaker: govornik_1, SNR condition: SNR_+2
#
# speech_mask_filenames: ['S3aba.wav', 'S3aca.wav'] ... (total 21)
#
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3aba_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3aca_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3ada_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3afa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3aga_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3aha_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3aja_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3aka_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3ala_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3ama_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3ana_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3apa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3ara_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3asa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3ata_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3ava_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3aza_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3ača_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3ađa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3aša_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g1 VCV mask\S3aža_spec.png
# Processing speaker: govornik_2, SNR condition: SNR_-2
#
# speech_mask_filenames: ['S1aba.wav', 'S1aca.wav'] ... (total 21)
#
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1aba_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1aca_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1ada_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1afa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1aga_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1aha_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1aja_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1aka_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1ala_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1ama_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1ana_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1apa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1ara_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1asa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1ata_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1ava_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1aza_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1ača_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1ađa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1aša_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S1aža_spec.png
# Processing speaker: govornik_2, SNR condition: SNR_+0
#
# speech_mask_filenames: ['S2aba.wav', 'S2aca.wav'] ... (total 21)
#
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2aba_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2aca_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2ada_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2afa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2aga_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2aha_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2aja_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2aka_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2ala_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2ama_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2ana_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2apa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2ara_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2asa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2ata_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2ava_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2aza_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2ača_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2ađa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2aša_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S2aža_spec.png
# Processing speaker: govornik_2, SNR condition: SNR_+2
#
# speech_mask_filenames: ['S3aba.wav', 'S3aca.wav'] ... (total 21)
#
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3aba_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3aca_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3ada_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3afa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3aga_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3aha_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3aja_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3aka_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3ala_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3ama_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3ana_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3apa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3ara_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3asa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3ata_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3ava_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3aza_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3ača_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3ađa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3aša_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g2 VCV mask\S3aža_spec.png
# Processing speaker: govornik_3, SNR condition: SNR_-2
#
# speech_mask_filenames: ['S1aba.wav', 'S1aca.wav'] ... (total 21)
#
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1aba_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1aca_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1ada_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1afa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1aga_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1aha_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1aja_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1aka_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1ala_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1ama_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1ana_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1apa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1ara_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1asa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1ata_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1ava_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1aza_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1ača_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1ađa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1aša_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S1aža_spec.png
# Processing speaker: govornik_3, SNR condition: SNR_+0
#
# speech_mask_filenames: ['S2aba.wav', 'S2aca.wav'] ... (total 21)
#
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2aba_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2aca_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2ada_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2afa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2aga_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2aha_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2aja_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2aka_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2ala_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2ama_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2ana_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2apa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2ara_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2asa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2ata_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2ava_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2aza_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2ača_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2ađa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2aša_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S2aža_spec.png
# Processing speaker: govornik_3, SNR condition: SNR_+2
#
# speech_mask_filenames: ['S3aba.wav', 'S3aca.wav'] ... (total 21)
#
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3aba_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3aca_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3ada_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3afa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3aga_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3aha_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3aja_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3aka_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3ala_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3ama_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3ana_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3apa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3ara_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3asa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3ata_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3ava_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3aza_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3ača_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3ađa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3aša_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g3 VCV mask\S3aža_spec.png
# Processing speaker: govornik_4, SNR condition: SNR_-2
#
# speech_mask_filenames: ['S1aba.wav', 'S1aca.wav'] ... (total 21)
#
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1aba_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1aca_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1ada_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1afa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1aga_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1aha_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1aja_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1aka_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1ala_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1ama_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1ana_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1apa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1ara_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1asa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1ata_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1ava_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1aza_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1ača_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1ađa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1aša_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S1aža_spec.png
# Processing speaker: govornik_4, SNR condition: SNR_+0
#
# speech_mask_filenames: ['S2aba.wav', 'S2aca.wav'] ... (total 21)
#
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2aba_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2aca_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2ada_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2afa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2aga_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2aha_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2aja_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2aka_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2ala_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2ama_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2ana_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2apa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2ara_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2asa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2ata_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2ava_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2aza_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2ača_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2ađa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2aša_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S2aža_spec.png
# Processing speaker: govornik_4, SNR condition: SNR_+2
#
# speech_mask_filenames: ['S3aba.wav', 'S3aca.wav'] ... (total 21)
#
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3aba_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3aca_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3ada_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3afa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3aga_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3aha_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3aja_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3aka_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3ala_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3ama_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3ana_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3apa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3ara_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3asa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3ata_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3ava_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3aza_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3ača_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3ađa_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3aša_spec.png
# C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\Diplomski Rad\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\wav g4 VCV mask\S3aža_spec.png
#
# len(data): 3
# data.keys(): dict_keys(['SNR_-2', 'SNR_+0', 'SNR_+2'])
#
# CPU times: total: 6min 19s
# Wall time: 2min 11s

# %% [markdown]
# ## Verify dict is good

# %%
print(f"len(data): {len(data)}")  # Prints the number of keys at the top level of data
print(f"data.keys(): {data.keys()}\n")  # Prints all keys at the top level of data
print(f"data['SNR_-2'].keys(): {(data['SNR_-2'].keys())}")
print(f"len(data['SNR_-2'].keys()): {len(data['SNR_-2'].keys())}\n")  # Prints the number of keys at the next level (assuming snr[0] exists in data)

print(f"data['SNR_-2']['govornik_1'].keys(): {(data['SNR_-2']['govornik_1'].keys())}")
print(f"len(data['SNR_-2'].keys()): {len(data['SNR_-2']['govornik_1'].keys())}\n")  # Prints the number of keys at the next level (assuming snr[0] exists in data)

print(f"data['SNR_-2']['govornik_1']['apa'].keys(): {(data['SNR_-2']['govornik_1']['apa'].keys())}")
print(f"len(data['SNR_-2']['govornik_1']['apa'].keys()): {len(data['SNR_-2']['govornik_1']['apa'])}\n")  # Prints the number of keys at the next level (assuming snr[0] exists in data)

#print(f"data['SNR_-2']['govornik_1']['apa'].keys(): {(data['SNR_-2']['govornik_1']['apa'].keys())}")
print(f"len(data[glimpses_mfcc].keys()): {len(data['SNR_-2']['govornik_1']['apa']['glimpses_mfcc'])}\n\n")  # Prints the number of keys at the next level (assuming snr[0] exists in data)

# Example: Print a sample from glimpses_mfcc_test
snr_condition_test = 'SNR_+2'  # Replace with your desired SNR condition
speaker_test = 'govornik_1'  # Replace with your desired speaker
stimulus_test = 'apa'  # Replace with your desired stimulus key

# Access glimpses_mfcc_test from data structure
if snr_condition_test in data and speaker_test in data[snr_condition_test] and stimulus_test in data[snr_condition_test][speaker_test]:
    glimpses_mfcc_test = data[snr_condition_test][speaker_test][stimulus_test]['glimpses_mfcc']
    
    # Print shape and a sample portion
    print(f"TENSOR PRINT:\n\n glimpses_mfcc_test Shape: {glimpses_mfcc_test.shape}")
    print("Sample from glimpses_mfcc_test:")
    print(glimpses_mfcc_test[:8, :5])  # Adjust the slice as per your requirement
else:
    print(f"Data not found for snr_condition_test={snr_condition_test}, speaker_test={speaker_test}, stimulus_test={stimulus_test}")
# Out:
# len(data): 3
# data.keys(): dict_keys(['SNR_-2', 'SNR_+0', 'SNR_+2'])
#
# data['SNR_-2'].keys(): dict_keys(['govornik_1', 'govornik_2', 'govornik_3', 'govornik_4'])
# len(data['SNR_-2'].keys()): 4
#
# data['SNR_-2']['govornik_1'].keys(): dict_keys(['apa', 'ata', 'aka', 'aba', 'ada', 'aga', 'asa', 'aša', 'aza', 'aža', 'afa', 'aha', 'aca', 'ača', 'ađa', 'aja', 'ana', 'ama', 'ara', 'ala', 'ava'])
# len(data['SNR_-2'].keys()): 21
#
# data['SNR_-2']['govornik_1']['apa'].keys(): dict_keys(['original', 'mask', 'glimpses_mel', 'glimpses_mfcc'])
# len(data['SNR_-2']['govornik_1']['apa'].keys()): 4
#
# len(data[glimpses_mfcc].keys()): 1
#
#
# TENSOR PRINT:
#
#  glimpses_mfcc_test Shape: torch.Size([1, 13, 107])
# Sample from glimpses_mfcc_test:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.8569, 0.7442, 0.7174, 0.7760, 0.7147, 0.7673,
#           0.8111, 0.8163, 0.8320, 0.8888, 0.6476, 0.7456, 0.8113, 0.8714,
#           0.9097, 0.8270, 0.8212, 0.9182, 0.8218, 0.9893, 1.0000, 0.9081,
#           0.8268, 0.7383, 0.7832, 0.8486, 0.8164, 0.7606, 0.8148, 0.6751,
#           0.6959, 0.0000, 0.0000, 0.6618, 0.6438, 0.6453, 0.0000, 0.0000,
#           0.6376, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6636, 0.0000, 0.6798,
#           0.6499, 0.7115, 0.7947, 0.6622, 0.7964, 0.6282, 0.7444, 0.7159,
#           0.7762, 0.6549, 0.6568, 0.0000, 0.0000, 0.6568, 0.7333, 0.7052,
#           0.0000, 0.6939, 0.7886, 0.6559, 0.6858, 0.6573, 0.6912, 0.6781,
#           0.6676, 0.6327, 0.7337, 0.7101, 0.7389, 0.6668, 0.0000, 0.0000,
#           0.6579, 0.6835, 0.6545, 0.6359, 0.0000, 0.6491, 0.6307, 0.6424,
#           0.6427, 0.0000, 0.0000],
#          [0.6286, 0.6234, 0.6651, 0.0000, 0.6347, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.6296, 0.0000, 0.6387, 0.0000, 0.0000, 0.6731, 0.6988,
#           0.7277, 0.6979, 0.6579, 0.7093, 0.6907, 0.7079, 0.8169, 0.7471,
#           0.7419, 0.6456, 0.6563, 0.7700, 0.7135, 0.6854, 0.7576, 0.7146,
#           0.6877, 0.0000, 0.0000, 0.6811, 0.6538, 0.6357, 0.0000, 0.6279,
#           0.6356, 0.0000, 0.0000, 0.0000, 0.0000, 0.6255, 0.6230, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.6259, 0.6257, 0.6227, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6908, 0.6633, 0.7296,
#           0.7109, 0.7265, 0.7484, 0.7200, 0.7848, 0.6538, 0.6541, 0.6506,
#           0.6598, 0.6574, 0.6267, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.6600, 0.0000, 0.6694, 0.0000, 0.6599, 0.6553,
#           0.6839, 0.6377, 0.7677, 0.7288, 0.7193, 0.7036, 0.0000, 0.0000,
#           0.6582, 0.6847, 0.6578, 0.6318, 0.0000, 0.6470, 0.6295, 0.6471,
#           0.6402, 0.6289, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.6295, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.6369, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6846, 0.7366,
#           0.6661, 0.0000, 0.0000, 0.6724, 0.6494, 0.6384, 0.0000, 0.0000,
#           0.6308, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.6531, 0.6885, 0.0000, 0.6607,
#           0.6615, 0.6520, 0.0000, 0.6426, 0.6833, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.6318, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6308, 0.0000,
#           0.6406, 0.0000, 0.7172, 0.7441, 0.7108, 0.6667, 0.0000, 0.0000,
#           0.6337, 0.6547, 0.6419, 0.6333, 0.0000, 0.6404, 0.6373, 0.6425,
#           0.6367, 0.0000, 0.0000],
#          [0.6268, 0.0000, 0.0000, 0.0000, 0.6422, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.6904, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6382, 0.7537,
#           0.6500, 0.0000, 0.0000, 0.6900, 0.6583, 0.6343, 0.0000, 0.6263,
#           0.6273, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.6955, 0.6800, 0.6316, 0.7055,
#           0.7109, 0.6271, 0.0000, 0.6403, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.6394, 0.0000, 0.6490, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6835, 0.6351,
#           0.6505, 0.0000, 0.7189, 0.7523, 0.7042, 0.6836, 0.0000, 0.0000,
#           0.6521, 0.6581, 0.6449, 0.6237, 0.0000, 0.6394, 0.6375, 0.6424,
#           0.6331, 0.6233, 0.0000]]])

# %%
# Function to recursively print sample data points including glimpses_mel and glimpses_mfcc
def print_sample_data_recursive(data, level=0, max_depth=3, num_samples=3):
    if level >= max_depth:
        return
    
    for key, value in data.items():
        if isinstance(value, dict):
            print('\t' * level + f"{key}:")
            print_sample_data_recursive(value, level + 1, max_depth, num_samples)
        elif isinstance(value, np.ndarray):
            print('\t' * level + f"{key} Shape: {value.shape}")
            if key == 'glimpses_mel' or key == 'glimpses_mfcc':
                print('\t' * level + f"{key} Example:")
                print(value[:8, :5])  # Print a small portion of the ndarray
                num_samples -= 1
                if num_samples <= 0:
                    return

# Function to dynamically determine maximum depth and call recursive function
def print_sample_data(data, max_depth=3, num_samples=3):
    print(f"Data Structure Analysis (up to depth {max_depth}):")
    print_sample_data_recursive(data, 0, max_depth, num_samples)

# Call the function to print sample data points
print_sample_data(data)

# %% [markdown]
# ## Save new dict (458MB)

# %%
import pickle
output_file_path_base = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV"
dictionary_name_version = f"\Mel_data_dict-{work_version}.pkl"

output_file_path = output_file_path_base + dictionary_name_version

# Save the dictionary using pickle
with open(output_file_path, "wb") as file:
    pickle.dump(data, file)

print(f"Dictionary saved to {output_file_path}")
# Out:
# Dictionary saved to C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\Mel_data_dict-v5.2mfcc.pkl

# %% [markdown]
# ## Load old dict

# %%
import pickle
import os

output_file_path_base = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV"
dictionary_name_version = f"Mel_data_dict-{work_version}.pkl"

old_default = "Mel_data_dict-v5.2mfcc.pkl"

# Construct full paths
output_file_path = os.path.join(output_file_path_base, dictionary_name_version)
old_default_path = os.path.join(output_file_path_base, old_default)

try:
    with open(output_file_path, "rb") as file:
        data = pickle.load(file)
    print(f"Dictionary loaded successfully! ({dictionary_name_version})")
except FileNotFoundError:
    print(f"File not found: {dictionary_name_version}. Using {old_default} instead.")
    try:
        with open(old_default_path, "rb") as file:
            data = pickle.load(file)
        print(f"Dictionary loaded successfully! ({old_default})")
    except FileNotFoundError:
        print(f"Default file {old_default} not found at {old_default_path}.")
    except Exception as e:
        print(f"Error loading default file {old_default}: {e}")
except Exception as e:
    print(f"Error loading dictionary {dictionary_name_version}: {e}")
# Out:
# File not found: Mel_data_dict-v6.0.pkl. Using Mel_data_dict-v5.2mfcc.pkl instead.
# Dictionary loaded successfully! (Mel_data_dict-v5.2mfcc.pkl)

# %% [markdown]
# # [8] Combining three avgMFCC as PNGs (across SNRs) works like a charm

# %% [markdown]
# ## Glimpse avgMFCC GENERATE

# %%
import numpy as np
import torch
import torchaudio
import os
import matplotlib.pyplot as plt

def find_longest_time_length(data, selected_speakers, selected_noise_condition, glimpse_type='glimpses_mel'):
    longest_length = 0
    try:
        for stimulus in data[selected_noise_condition][selected_speakers[0]]:
            for speaker in selected_speakers:
                glimpses_length = data[selected_noise_condition][speaker][stimulus][glimpse_type].shape[2]  # Get the length along the time axis
                if glimpses_length > longest_length:
                    longest_length = glimpses_length
    except TypeError as e:
        print(f"Error: {e}")
        print(f"selected_speakers: {selected_speakers}")
        print(f"selected_noise_condition: {selected_noise_condition}")
        #print(f"data[selected_noise_condition]: {data[selected_noise_condition]}")
        #print(f"data[selected_noise_condition][selected_speakers[0]]: {data[selected_noise_condition][selected_speakers[0]]}")
    except KeyError as e:
        print(f"KeyError: {e}")
    return longest_length


# Function to pad glimpses to the longest time length equally on both sides
def pad_glimpses(glimpses, longest_length):
    current_length = glimpses.shape[1]
    if current_length < longest_length:
        total_padding = longest_length - current_length
        left_padding = total_padding // 2
        right_padding = total_padding - left_padding
        pad_width = ((0, 0), (left_padding, right_padding))
        return np.pad(glimpses, pad_width, mode='constant', constant_values=0)
    else:
        return glimpses

# Function to calculate the average glimpses for each stimulus
def calculate_average_glimpses_mel(data, selected_speakers, selected_noise_condition):
    average_glimpses = {}
    longest_length = find_longest_time_length(data, selected_speakers, selected_noise_condition)
    
    # print(f"Longest time length found: {longest_length}")

    # Pad the glimpses and calculate the average glimpses for each stimulus
    for stimulus in data[selected_noise_condition][selected_speakers[0]]:
        glimpses_sum = None
        
        # Iterate over each speaker for the current stimulus
        for speaker in selected_speakers:
            glimpses = data[selected_noise_condition][speaker][stimulus]['glimpses_mel'].squeeze().numpy()  # Ensure it's a 2D array
            padded_glimpses = pad_glimpses(glimpses, longest_length)
            
            # print(f"Speaker: {speaker}, Stimulus: {stimulus}, Original shape: {glimpses.shape}, Padded shape: {padded_glimpses.shape}")

            # Initialize glimpses_sum if it's None
            if glimpses_sum is None:
                glimpses_sum = padded_glimpses
            else:
                # Add the padded glimpses to the existing sum
                glimpses_sum += padded_glimpses
        
        # Calculate the average glimpses for the current stimulus
        average_glimpses[stimulus] = glimpses_sum / len(selected_speakers)
    
    return average_glimpses

# Function to calculate the average glimpses for each stimulus
def calculate_average_glimpses_mfcc(data, selected_speakers, selected_noise_condition):
    average_glimpses = {}
    longest_length = find_longest_time_length(data, selected_speakers, selected_noise_condition)
    
    # print(f"Longest time length found: {longest_length}")

    # Pad the glimpses and calculate the average glimpses for each stimulus
    for stimulus in data[selected_noise_condition][selected_speakers[0]]:
        glimpses_sum = None
        
        # Iterate over each speaker for the current stimulus
        for speaker in selected_speakers:
            glimpses = data[selected_noise_condition][speaker][stimulus]['glimpses_mfcc'].squeeze().numpy()  # Ensure it's a 2D array
            padded_glimpses = pad_glimpses(glimpses, longest_length)
            
            # print(f"Speaker: {speaker}, Stimulus: {stimulus}, Original shape: {glimpses.shape}, Padded shape: {padded_glimpses.shape}")

            # Initialize glimpses_sum if it's None
            if glimpses_sum is None:
                glimpses_sum = padded_glimpses
            else:
                # Add the padded glimpses to the existing sum
                glimpses_sum += padded_glimpses
        
        # Calculate the average glimpses for the current stimulus
        average_glimpses[stimulus] = glimpses_sum / len(selected_speakers)
    
    return average_glimpses

print("Functions online.")
# Out:
# Functions online.

# %%
# save9_png_path = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\PNG analiza mel3"
# print(f"Saving to folder...\n {save9_png_path}")

# %%
save9_png_path = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\PNG analiza mm3"
print(f"Saving to folder...\n {save9_png_path}")
# Out:
# Saving to folder...
#  C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV\PNG analiza mm3

# %% [markdown]
# ## A bit of fun before generation (Custom tick marks)

# %%
import numpy as np

# Constants
sample_rate = 44100
max_freq = 22050  # Half of the sample rate (Nyquist frequency)
n_mels = 64
tick_number = 6  # Number of ticks you want on the plot

# Convert max frequency to Mel scale
max_mel = 2595 * np.log10(1 + max_freq / 700)

# Compute the spacing between each Mel frequency bin
mel_bin_width = max_mel / (n_mels - 1)

# Generate Mel frequency bin values and round them to the nearest integer
mel_bins = [int(round(mel_bin_width * i)) for i in range(n_mels)]

# Convert Mel frequency bins back to Hz for plotting and round to nearest integer
freq_bins = [int(round(700 * (10**(mel/2595) - 1))) for mel in mel_bins]

print(f"Mel frequency bins (rounded): {len(mel_bins)}")
print(f"Corresponding frequency bins (Hz, rounded): {len(freq_bins)} \n")
# print(f"Mel frequency bins (rounded): {mel_bins}")
# print(f"Corresponding frequency bins (Hz, rounded): {freq_bins}")

# Function to select equidistant ticks
def select_ticks(freq_bins, tick_number):
    indices = np.linspace(0, len(freq_bins) - 1, tick_number, dtype=int)
    selected_ticks = [freq_bins[i] for i in indices]
    return selected_ticks

# Select ticks
selected_ticks = select_ticks(freq_bins, tick_number)

print(f"Selected ticks (Hz): {selected_ticks}")
selected_ticks = [0, 600, 2000, 4700, 10000, 22000]
print(f"Selected ticks (Hz): {selected_ticks}")
# Out:
# Mel frequency bins (rounded): 64
# Corresponding frequency bins (Hz, rounded): 64
#
# Selected ticks (Hz): [0, 658, 2087, 4707, 10394, 22043]
# Selected ticks (Hz): [0, 600, 2000, 4700, 10000, 22000]

# %%
import numpy as np

# Define your parameters
sr = 44100
hop_length = 160
win_length = 400

# Example glimpses shape (this would come from your data)
glimpses_shape_1 = 128  # Example value, replace with glimpses.shape[1] from your actual data

# Calculate duration per frame
duration_per_frame = hop_length / sr

# Calculate total duration
total_duration = glimpses_shape_1 * duration_per_frame

# Define the number of ticks
num_ticks = 6

# Calculate tick positions and labels
tick_positions = np.linspace(0, glimpses_shape_1, num_ticks)
tick_labels = [f"{tick:.2f} s" if idx == num_ticks - 1 else f"{tick:.2f}" for idx, tick in enumerate(np.linspace(0, total_duration, num_ticks))]

print(f"selected tick_labels {tick_labels}")
# Out:
# selected tick_labels ['0.00', '0.09', '0.19', '0.28', '0.37', '0.46 s']

# %% [markdown]
# # The Generation of PNGs

# %%
samplerate_path = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrada 3 VCV"
samplerate_path2 = samplerate_path + "\wav g4 VCV mask"

selected_speakers = ['govornik_1', 'govornik_2','govornik_3', 'govornik_4']

speaker_folders = ["1", "2", "3", "4"]


_, sr = torchaudio.load(samplerate_path2 + r"\S3aca.wav")

longest_duration = 0
longest_filename = None

for speeks in speaker_folders:
    # Iterate over all files in the directory
    for filename in os.listdir(samplerate_path2):
        # Check if the file is a WAV file
        if filename.endswith(".wav"):
            # Get the full path to the WAV file

            speeko = f"\wav g{speaker_folders[int(speeks)-1]} VCV mask"

            speeks_path = samplerate_path + speeko

            file_path = os.path.join(speeks_path, filename)
            
            #print(file_path)
            
            # Get information about the WAV file
            info = torchaudio.info(file_path)
            
            # Calculate the duration of the WAV file in seconds
            duration_seconds = info.num_frames / info.sample_rate
            
            # Check if this file has the longest duration so far
            if duration_seconds > longest_duration:
                longest_duration = duration_seconds
                longest_filename = filename 

print(f"Longest filename: {speeko}\ {longest_filename}")
print(f"Duration of the audio: {duration_seconds:.4f} seconds\n")
# Out:
# Longest filename: \wav g4 VCV mask\ S1aca.wav
# Duration of the audio: 0.4363 seconds

# %% [markdown]
# # MEL pngs ONLY

# %%
# %%time

###### TIME TO GENERATE A BUNCH OF PNGs ##########
#################################################

selected_speakers = ['govornik_1', 'govornik_2','govornik_3', 'govornik_4']

print(f"Data from Mel generation:\n sample rate: {sr}\n  n_mels {n_mels}\n  n_fft {n_fft}\n win_length {win_length}\n hop_length {hop_length}\n")

# Assuming you have a list of frequencies in kHz
frequencies_kHz = [0, 4, 8, 12, 16, 22]

# selected_ticks = [0, 600, 2000, 4700, 10000, 22000]
selected_ticks = [0, "0.6", "2.0", "4.7", "10", "22 kHz"]


mel_min = 0  # Minimum frequency in Mel scale
mel_max = 2595 * np.log10(1 + 22 / 700)  # Maximum frequency in Mel scale
mel_freq_plot = np.linspace(mel_min, mel_max, len(frequencies_kHz))


# glimpse_types = ['glimpses_mel', 'glimpses_mfcc']  # List of glimpse types to plot


for stimulus in calculate_average_glimpses_mel(data, selected_speakers, snr_conditions[0]).keys():
    fig, axes = plt.subplots(len(snr_conditions), 1, figsize=(8, 6 * len(snr_conditions)), sharex=True, sharey=True)
    
    for i, snr_condition in enumerate(snr_conditions):
        average_glimpses = calculate_average_glimpses_mel(data, selected_speakers, snr_condition)
        glimpses = average_glimpses[stimulus]

        #print(i)

        if i == 0:
            longest_length = find_longest_time_length(data, selected_speakers, snr_condition)
        
        ax = axes[i]
        cax = ax.pcolormesh(range(glimpses.shape[1]), range(glimpses.shape[0]), glimpses, shading='nearest', cmap='gray_r', vmin=0, vmax=1)
      
        # Replace underscores with spaces in snr_condition
        formatted_snr_condition = snr_condition.replace("_", " ")
        
        # Add a suffix string
        suffix_dB = "dB"  # Replace this with your desired suffix
        title_snr = f'{formatted_snr_condition} {suffix_dB}'
        
        # Set the title with the modified string
        ax.set_title(title_snr, fontsize=22, weight='bold', loc='left')

        # Create a second y-axis with a different scale
        ax2 = ax.twinx()
        ax2.set_ylim(0, n_mels - 1)  # Set the custom range for the second y-axis
        ax2.set_yticks(np.linspace(0, n_mels - 1, tick_number))  # Set custom ticks for the second y-axis
        ax2.set_yticklabels(selected_ticks, fontsize=10)  # Set custom tick labels for the second y-axis

        if i == 2:
            ax.xaxis.set_visible(True)
        else:
            ax.xaxis.set_visible(False)
            
        if i % 3 == 0:
                ax3 = ax.twiny()
                ax3.set_xlim(0, glimpses.shape[1])  # Set the custom range for the third x-axis
                ax3.set_xticks(tick_positions)  # Set custom ticks for the third x-axis
                ax3.set_xticklabels(tick_labels, fontsize=10)  # Set custom tick labels for the third x-axis
        
        if i == len(snr_conditions) // 2:
            str_ylabel = f"Mel Filterbanka ({n_mels} filtera)"
            ax.set_ylabel(str_ylabel, fontsize=18)  # Customizing ylabel font size
        
       #ax2.set_ylabel("kHz", fontsize=18, labelpad=20, loc="center", rotation=0)  # Custom label for the second y-axis
            
        
    # Common xlabel
    str_xlabel = f"Vrijeme ({longest_length} koraka)"
    fig.text(0.5, 0.07, str_xlabel, ha='center', fontsize=18, va='bottom')  # Customizing xlabel font size and aligning to the bottom
    
    # Add custom text above the stack
    title_card = f"/{stimulus}/"
    fig.text(0.5, 0.91, title_card, ha='center', fontsize=50, weight='bold')

    
    bottom_text_version = f"Version: {work_version}\n"
    mfcc_data_text = f"DATA: sr: {sr} | n_fft {n_fft}| n_mels {n_mels} | win_len {win_length} | hop_len {hop_length}"
    bottom_text = bottom_text_version + mfcc_data_text
    
    fig.text(0.5, 0.005, bottom_text, ha='center', fontsize=12, fontweight='bold')

    
    # Save the plot as a .png file in the current directory
    speaker_suffix = '+'.join([speaker_mapping[speaker] for speaker in selected_speakers])
    snr_prefix = '_'.join([snr_prefix_mapping[snr] for snr in snr_conditions])
    
    output_filename_png = f'mel_{stimulus}_combined_avg_glimpses_{snr_prefix}-{speaker_suffix}_{work_version}.png'.replace(' ', '_')
    save_png_string = os.path.join(save9_png_path, output_filename_png)
    
    fig.savefig(save_png_string, format='png', bbox_inches='tight')
    
    # Close the figure
    plt.close(fig)
        
    print(f"Plotted: Stimulus {stimulus}, all SNRs, Glimpse Type MEL (hardcoded)")


print(f"\nAll plots and processing completed.")

print(f"longest_length: {longest_length} frames")

print(f"\n alot generated")
# Out:
# Data from Mel generation:
#  sample rate: 44100
#   n_mels 64
#   n_fft 400
#  win_length 400
#  hop_length 160
#
# Plotted: Stimulus apa, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus ata, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus aka, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus aba, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus ada, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus aga, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus asa, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus aša, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus aza, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus aža, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus afa, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus aha, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus aca, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus ača, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus ađa, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus aja, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus ana, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus ama, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus ara, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus ala, all SNRs, Glimpse Type MEL (hardcoded)
# Plotted: Stimulus ava, all SNRs, Glimpse Type MEL (hardcoded)
#
# All plots and processing completed.
# longest_length: 128 frames
#
#  alot generated
# CPU times: total: 9.22 s
# Wall time: 9.49 s

# %% [markdown]
# # MFCC pngs ONLY

# %%
# %%time

###### TIME TO GENERATE A BUNCH OF PNGs ##########
#################################################

selected_speakers = ['govornik_1', 'govornik_2','govornik_3', 'govornik_4']

print(f"Data from MFCC generation:\n sample rate: {sr}\n  n_fft {n_fft}\n win_length {win_length}\n hop_length {hop_length}\n n_mels {n_mels}\n ")

# Assuming you have a list of frequencies in kHz
frequencies_kHz = [0, 4, 8, 12, 16, 22]

# selected_ticks = [0, 600, 2000, 4700, 10000, 22000]
selected_ticks = [0, "0.6", "2.0", "4.7", "10", "22 kHz"]


mel_min = 0  # Minimum frequency in Mel scale
mel_max = 2595 * np.log10(1 + 22 / 700)  # Maximum frequency in Mel scale
mel_freq_plot = np.linspace(mel_min, mel_max, len(frequencies_kHz))


# glimpse_types = ['glimpses_mel', 'glimpses_mfcc']  # List of glimpse types to plot


for stimulus in calculate_average_glimpses_mfcc(data, selected_speakers, snr_conditions[0]).keys():
    fig, axes = plt.subplots(len(snr_conditions), 1, figsize=(8, 6 * len(snr_conditions)), sharex=True, sharey=True)
    
    for i, snr_condition in enumerate(snr_conditions):
        average_glimpses = calculate_average_glimpses_mfcc(data, selected_speakers, snr_condition)
        glimpses = average_glimpses[stimulus]

        #print(i)

        if i == 0:
            longest_length = find_longest_time_length(data, selected_speakers, snr_condition)
        
        ax = axes[i]
        cax = ax.pcolormesh(range(glimpses.shape[1]), range(glimpses.shape[0]), glimpses, shading='nearest', cmap='gray_r', vmin=0, vmax=1)
        ax.set_ylim(1, n_mfcc - 1)  # Set the custom range for the first y-axis
        
        # Replace underscores with spaces in snr_condition
        formatted_snr_condition = snr_condition.replace("_", " ")
        
        # Add a suffix string
        suffix_dB = "dB"  # Replace this with your desired suffix
        title_snr = f'{formatted_snr_condition} {suffix_dB}'
        
        # Set the title with the modified string
        ax.set_title(title_snr, fontsize=22, weight='bold', loc='left')
        

        # Create a second y-axis with a different scale
        ax2 = ax.twinx()
        ax2.yaxis.set_visible(False)
        ax2.set_ylim(1, n_mfcc - 1)  # Set the custom range for the second y-axis
        ax2.set_yticks(np.linspace(1, n_mfcc - 1, tick_number))  # Set custom ticks for the second y-axis
        ax2.set_yticklabels(selected_ticks, fontsize=10)  # Set custom tick labels for the second y-axis

        if i == 2:
            ax.xaxis.set_visible(True)
        else:
            ax.xaxis.set_visible(False)
            
        if i % 3 == 0:
                ax3 = ax.twiny()
                ax3.set_xlim(0, glimpses.shape[1])  # Set the custom range for the third x-axis
                ax3.set_xticks(tick_positions)  # Set custom ticks for the third x-axis
                ax3.set_xticklabels(tick_labels, fontsize=10)  # Set custom tick labels for the third x-axis
        
        if i == len(snr_conditions) // 2:
            str_ylabel = f"MFCC koeficijenti"
            ax.set_ylabel(str_ylabel, fontsize=18)  # Customizing ylabel font size
        
       #ax2.set_ylabel("kHz", fontsize=18, labelpad=20, loc="center", rotation=0)  # Custom label for the second y-axis
            
        
    # Common xlabel
    str_xlabel = f"Vrijeme ({longest_length} koraka)"
    fig.text(0.5, 0.07, str_xlabel, ha='center', fontsize=18, va='bottom')  # Customizing xlabel font size and aligning to the bottom
    
    # Add custom text above the stack
    title_card = f"/{stimulus}/"
    fig.text(0.5, 0.91, title_card, ha='center', fontsize=50, weight='bold')

    
    bottom_text_version = f"Version: {work_version}\n"
    mfcc_data_text = f"DATA: sr: {sr} | n_mfcc {n_mfcc} | n_fft {n_fft}| n_mels {n_mels} | win_len {win_length} | hop_len {hop_length}"
    bottom_text = bottom_text_version + mfcc_data_text
    
    fig.text(0.5, 0.005, bottom_text, ha='center', fontsize=12, fontweight='bold')

    
    # Save the plot as a .png file in the current directory
    speaker_suffix = '+'.join([speaker_mapping[speaker] for speaker in selected_speakers])
    snr_prefix = '_'.join([snr_prefix_mapping[snr] for snr in snr_conditions])
    
    output_filename_png = f'mfcc_{stimulus}_combined_avg_glimpses_{snr_prefix}-{speaker_suffix}_{work_version}.png'.replace(' ', '_')
    save_png_string = os.path.join(save9_png_path, output_filename_png)
    
    fig.savefig(save_png_string, format='png', bbox_inches='tight')
    
    # Close the figure
    plt.close(fig)
        
    print(f"Plotted: Stimulus {stimulus}, all SNRs, Glimpse Type MFCC (hardcoded)")


print(f"\nAll plots and processing completed.")

print(f"longest_length: {longest_length} frames")

print(f"\n alot generated")
# Out:
# Data from MFCC generation:
#  sample rate: 44100
#   n_fft 400
#  win_length 400
#  hop_length 160
#  n_mels 64
#
# Plotted: Stimulus apa, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus ata, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus aka, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus aba, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus ada, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus aga, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus asa, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus aša, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus aza, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus aža, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus afa, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus aha, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus aca, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus ača, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus ađa, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus aja, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus ana, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus ama, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus ara, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus ala, all SNRs, Glimpse Type MFCC (hardcoded)
# Plotted: Stimulus ava, all SNRs, Glimpse Type MFCC (hardcoded)
#
# All plots and processing completed.
# longest_length: 128 frames
#
#  alot generated
# CPU times: total: 7.03 s
# Wall time: 7.41 s

# %% [markdown]
# ## Bring up a PNG to check

# %%
from IPython.display import Image

Image(save_png_string)

# %% [markdown]
# # LTAS plotting

# %%
import torch
import torchaudio

# Load audio files using torchaudio
path_speech1 = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrađeno 2 Audacity i Python\joined_1_to_21_68.wav"

path_mask1 = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrađeno 2 Audacity i Python\SSN_g1_68.wav"


# Load audio files using torchaudio
path_speech2 = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrađeno 2 Audacity i Python\joined_22_to_42_68.wav"

path_mask2 = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrađeno 2 Audacity i Python\SSN_g2_68.wav"


# Load audio files using torchaudio
path_speech3 = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrađeno 2 Audacity i Python\joined_43_to_63_68.wav"

path_mask3 = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrađeno 2 Audacity i Python\SSN_g3_68.wav"

# Load audio files using torchaudio
path_speech4 = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrađeno 2 Audacity i Python\joined_64_to_84_68.wav"

path_mask4 = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrađeno 2 Audacity i Python\SSN_g4_68.wav"


speech_tensor1, sr_speech1 = torchaudio.load(path_speech1)
mask_tensor1, sr_mask1 = torchaudio.load(path_mask1)

speech_tensor2, sr_speech2 = torchaudio.load(path_speech2)
mask_tensor2, sr_mask2 = torchaudio.load(path_mask2)

speech_tensor3, sr_speech3 = torchaudio.load(path_speech3)
mask_tensor3, sr_mask3 = torchaudio.load(path_mask3)

speech_tensor4, sr_speech4 = torchaudio.load(path_speech4)
mask_tensor4, sr_mask4 = torchaudio.load(path_mask4)



print("loaded audio")
# Out:
# loaded audio

# %%
def compute_ltas(audio_tensor, sr, n_fft=2048, hop_length=512, win_length=512, window='hann'):
    # Create the window function
    window_function = torch.hann_window(win_length) if window == 'hann' else torch.hamming_window(win_length)
    
    # Compute STFT
    stft = torch.stft(audio_tensor, n_fft=n_fft, hop_length=hop_length, win_length=win_length, window=window_function, return_complex=True)
    
    # Compute magnitude
    magnitude = torch.abs(stft)
    
    # Convert magnitude to decibels (logarithmic scale)
    eps = 1e-10  # Small constant to avoid log(0)
    magnitude_db = 20 * torch.log10(magnitude + eps)
    
    # Average over time (dimension -1 corresponds to time)
    ltas_db = torch.mean(magnitude_db, dim=-1)
    
    # Normalize LTAS to full-scale dB (0 dB down to negative values)
    max_value = ltas_db.max()
    ltas_full_scale = ltas_db - max_value
    
    # Compute frequency bins
    freqs = torch.fft.fftfreq(n_fft, d=1/sr)[:n_fft//2]
    
    return ltas_full_scale[:n_fft//2], freqs


win_length = 1024*30 # 2048
n_fft = win_length # 2048
hop_length = 512 # 512

ltas_speech, freqs_speech = compute_ltas(speech_tensor1[0], sr_speech1, n_fft=n_fft, hop_length=hop_length, win_length=win_length)
ltas_mask, freqs_mask = compute_ltas(mask_tensor1[0], sr_mask1, n_fft=n_fft, hop_length=hop_length, win_length=win_length)

print("did ltas")
# Out:
# did ltas

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import torchaudio
import torch
from scipy.interpolate import make_interp_spline
from matplotlib.ticker import FuncFormatter
import parselmouth
from parselmouth.praat import call


win_length = 1024*30 # 2048
n_fft = win_length # 2048
hop_length = 512 # 512


# Function to compute LTAS from audio tensor
def compute_ltas(audio_tensor, sr, n_fft=2048, hop_length=512, win_length=512, window='hann'):
    # Create the window function
    window_function = torch.hann_window(win_length) if window == 'hann' else torch.hamming_window(win_length)
    
    # Compute STFT
    stft = torch.stft(audio_tensor, n_fft=n_fft, hop_length=hop_length, win_length=win_length, window=window_function, return_complex=True)
    
    # Compute magnitude
    magnitude = torch.abs(stft)
    
    # Convert magnitude to decibels (logarithmic scale)
    eps = 1e-10  # Small constant to avoid log(0)
    magnitude_db = 20 * torch.log10(magnitude + eps)
    
    # Average over time (dimension -1 corresponds to time)
    ltas_db = torch.mean(magnitude_db, dim=-1)
    
    # Normalize LTAS to full-scale dB (0 dB down to negative values)
    max_value = ltas_db.max()
    ltas_full_scale = ltas_db - max_value
    
    # Compute frequency bins
    freqs = torch.fft.fftfreq(n_fft, d=1/sr)[:n_fft//2]
    
    return ltas_full_scale[:n_fft//2], freqs

# Directory to save plots
save11_ltas_path = r"C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrađeno 2 Audacity i Python"

print(f"saving to: {save11_ltas_path}\n work version: {work_version}")



# Iterate over each pair of speech and mask files
for i, (speech_tensor, mask_tensor) in enumerate([(speech_tensor1, mask_tensor1),
                                                  (speech_tensor2, mask_tensor2),
                                                  (speech_tensor3, mask_tensor3),
                                                  (speech_tensor4, mask_tensor4)], start=1):
    # Compute LTAS for speech and mask
    ltas_speech, freqs_speech = compute_ltas(speech_tensor[0], sr_speech1, n_fft=n_fft, hop_length=hop_length, win_length=win_length)
    ltas_mask, freqs_mask = compute_ltas(mask_tensor[0], sr_mask1, n_fft=n_fft, hop_length=hop_length, win_length=win_length)

    # Define the frequency range of interest for F0
    min_freq = 80
    max_freq = 350

    # Find the strongest frequency and its value for speech within the specified range
    speech_range = (freqs_speech >= min_freq) & (freqs_speech <= max_freq)
    max_speech_idx = torch.argmax(ltas_speech[speech_range])
    max_speech_freq = freqs_speech[speech_range][max_speech_idx].item()
    max_speech_db = ltas_speech[speech_range][max_speech_idx].item()

    # Find the strongest frequency and its value for mask within the specified range
    mask_range = (freqs_mask >= min_freq) & (freqs_mask <= max_freq)
    max_mask_idx = torch.argmax(ltas_mask[mask_range])
    max_mask_freq = freqs_mask[mask_range][max_mask_idx].item()
    max_mask_db = ltas_mask[mask_range][max_mask_idx].item()

    # Shift the LTAS to make the highest point 0 dB
    ltas_speech_shifted = ltas_speech - max_speech_db

    if i == 1:
        ltas_mask_shifted = ltas_mask - max_mask_db
    elif i == 2:
        ltas_mask_shifted = ltas_mask - max_mask_db - 5
    elif i == 3:
        ltas_mask_shifted = ltas_mask - max_mask_db - 2
    elif i == 4:
        ltas_mask_shifted = ltas_mask - max_mask_db - 3

    # Function to format x-axis ticks
    def format_func(value, tick_number):
        if value < 1000:
            return f'{value/1000:.2f}'
        elif value < 10000:
            return f'{value/1000:.1f}'
        else:
            return f'{int(value/1000)}'

    
    # Convert speech_tensor to NumPy array (assuming it's already a torch tensor)
    speech_array = speech_tensor.numpy()[0]  # Assuming single-channel audio

    # Create Sound object from speech array
    sound = parselmouth.Sound(speech_array, sampling_frequency=sr_speech)

    # Extract pitch information using Praat's "To Pitch" function
    pitch = call(sound, "To Pitch", 0.0, 75, 600)
    
    # Compute mean pitch
    mean_pitch = call(pitch, "Get mean", 0, 0, "Hertz")
    
    # Print results
    print(f"Mean pitch: {mean_pitch:.2f} Hz")





    
    # Create the plot
    plt.figure(figsize=(12, 4))

    # Plot LTAS for speech
    # plt.plot(freqs_speech, ltas_speech_shifted, label=f'Govor (F0 = {max_speech_freq:.1f} Hz)', 
    #         linewidth=3, linestyle='-', color='#FFA500', alpha=1.0)

    plt.plot(freqs_speech, ltas_speech_shifted, label=f'Govor (F0 = {mean_pitch:.1f} Hz)', 
             linewidth=3, linestyle='-', color='#FFA500', alpha=1.0)
    # Plot LTAS for mask
    plt.plot(freqs_mask, ltas_mask_shifted, label=f'Maska', 
             linewidth=3, linestyle='-', color='#1f77b4', alpha=1.0)
    

    # Set the x-axis to a logarithmic scale
    plt.xscale('log')

    # Set custom x-axis limits (e.g., from 70 Hz to 12 kHz)
    plt.xlim(70, 12000)
    plt.ylim(-70, 5)
    plt.xticks([70, 100, 200, 500, 1000, 2000, 5000, 10000, 12000], 
               ['0.07', '0.1', '0.2', '0.5', '1k', '2k', '5k', '10k', '12k'])

    # Set x-axis formatter
    plt.gca().xaxis.set_major_formatter(FuncFormatter(format_func))


    # Set labels and title
    plt.xlabel('Frekvencija (kHz)')
    plt.ylabel('Intenzitet (dB)')
    plt.title(f'Long-Term Average Spectrum (LTAS) - Govornik {i}')

    # Add a grid
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)

    # Add a legend
    plt.legend()

    # Set plot name and save
    output_filename_ltas = f'ltas_{work_version}_govornik_{i}c.png'.replace(' ', '_')
    save_ltas_string = os.path.join(save_ltas_path, output_filename_ltas)
    
    plt.savefig(save_ltas_string, format='png', bbox_inches='tight')

    # Show the plot (optional)
    plt.show()

    # Close the plot to release memory
    plt.close()

    print(f'Plot saved as {output_filename_ltas}')
# Out:
# saving to: C:\Users\Mr Cab Driver\Documents\A FAKS FFZG\Diplomski\Fonetika\DIPLOMSKI RAD\Govorni materijal\Audio snimke govornika GM\Obrađeno 2 Audacity i Python
#  work version: v6.3
# Mean pitch: 219.30 Hz
# Plot saved as ltas_v6.3_govornik_1c.png
# Mean pitch: 120.58 Hz
# Plot saved as ltas_v6.3_govornik_2c.png
# Mean pitch: 228.08 Hz
# Plot saved as ltas_v6.3_govornik_3c.png
# Mean pitch: 127.13 Hz
# Plot saved as ltas_v6.3_govornik_4c.png

# %%
import parselmouth
from parselmouth.praat import call

# Load the audio file using Parselmouth
sound = parselmouth.Sound(path_speech1)

# Extract pitch information using Praat's "To Pitch" function
pitch = call(sound, "To Pitch", 0.0, 75, 600)

# Compute mean pitch
mean_pitch = call(pitch, "Get mean", 0, 0, "Hertz")

# Print results
print(f"Mean pitch: {mean_pitch:.2f} Hz")
# Out:
# Mean pitch: 219.30 Hz

# %% [markdown]
# # x scraps to delete later
